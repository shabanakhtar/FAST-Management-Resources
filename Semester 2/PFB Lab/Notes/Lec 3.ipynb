# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# ## Control structures, sequence structure and conditional statements

# %% [markdown]
# We’ll cover the essentials of Python’s control structures, including sequence structure ,
# conditional statements and keywords like break, continue, and pass.
# By the end, you’ll be able to make decisions in your code through data efficiently.
#
# * Introduction to Control Structures
# * Sequence Structure
# * Conditional Statements (if, elif, else)
# * Practical Examples

# %% [markdown]
# ## Control Structure
# ###  Control structure is a logical design that controls the oreder in which set of statements execute.

# %% [markdown]
# * **Sequence Structure**
#
# * **Decision Structure / Conditional Statements**

# %% [markdown]
# ### Sequence Structure
# #### A sequence structure is  set of statements that execute in the order in which they appear

# %%
name = input("What is your name?: ")
age  = input("What is your age?: ")
print("Name:", name)
print("Age:", age)
# Out:
# What is your name?: Talal
# What is your age?: 20
# Name: Talal
# Age: 20

# %% [markdown]
# ### Decision Structure / Conditional Statements
# #### Execute specific blocks of code based on whether a condition is True or False.

# %%
from IPython.display import Image, display

# %%
display(Image(filename="DecisionStructure.jpg"))

# %% [markdown]
# In Figure a **single alternative decision structure.**
# It provides only one alternative path of execution.If the condition in the diamond symbol is true, we take the alternative path.

# %%
temperature = 15

if temperature < 25:
    print("Wear a coat.")
# Out:
# Wear a coat.

# %% [markdown]
# Let’s understand the above code.
#
# The program first checks if the temperature is less than 25. If true, it prints “Wear a coat.”
#
# * Conditions use comparison operators (==, !=, >, <, >=, <=) and logical operators (and, or, not)   to combine multiple conditions.
# * Indentation defines the code block under each condition.

# %%
display(Image(filename="DualDecisionStructure.jpg"))

# %%
temperature = 25

if temperature < 40:
    print("A little cold, isn't it?")
else:
    print("Nice weather we're having.")
# Out:
# A little cold, isn't it?

# %% [markdown]
# Let’s understand the above code.
#
# The program first checks if the temperature is less than 40. If true, it prints “A little cold, isn't it?”.
#
# If above conditions is false, it executes the else block and prints “Nice weather we're having.”
#
# * Conditions use comparison operators (==, !=, >, <, >=, <=) and logical operators (and, or, not)   to combine multiple conditions.
# * Indentation defines the code block under each condition.

# %% [markdown]
# # if, elif, else Statements
#
# #### <code>if</code> Statements in Python allows us to tell the computer to perform alternative actions based on a certain set of results.
#
# #### The if statement is used to create a decision structure, which allows a program to have one or more than one path of execution. The if statement causes one or more statements to execute only when a Boolean expression is true.
#
# #### In Python, If-else is a fundamental conditional statement used for decision-making in programming. If...else statement allows to execution of specific blocks of code depending on the condition is True or False.
#
# Verbally, we can imagine we are telling the computer:
#
# "Hey if this case happens, perform some action"
#
# We can then expand the idea further with <code>elif</code> and <code>else</code> statements, which allow us to tell the computer:
#
# "Hey **if this case happens, perform some action. elif, if another case happens, perform some other action. else, if *none* of the above cases happened, perform this action."**
#
# **Python gets rid of () and {} by incorporating two main factors: a *colon* and *whitespace*. The statement is ended with a colon, and whitespace is used (indentation) to describe what takes place in case of the statement.**
#
# **Python reduces code clutter by replacing braces {} and parentheses () with colons (:) and mandatory indentation. A colon signifies the *start of a new, indented block of code, while the whitespace (usually 4 spaces) defines the scope, making code more readable and structured*.**
#
# **Another major difference is the lack of semicolons in Python. Semicolons are used to denote statement endings in many other languages, but in Python, the end of a line is the same as the end of a statement.**
#
# **Note how Python is so heavily driven by code indentation and whitespace. This means that code readability is a core part of the design of the Python language.**
#
# **Indentation**
#
# **Here is some pseudo-code to indicate the use of whitespace and indentation in Python.**
#
# Let's go ahead and look at the syntax format for <code>if</code> statements to get a better idea of this:
#
#
#
#     if case1:
#         perform action1
#
#     if case1:
#         perform action1
#     else:
#         perform action2
#
#     if case1:
#         perform action1
#     elif case2:
#         perform action2
#     else:
#         perform action3

# %% [markdown]
# **if Statement**
#
# <code>if statement</code> is the most simple decision-making statement. If the <code>condition</code> evaluates to <code>True</code>, the **block of code** inside the if statement is executed.

# %%
if True:
    print('It was true!')
# Out:
# It was true!

# %% [markdown]
# Let’s understand the above code.
#
# The program first checks if the condition is true, it prints “It was true!”
# * Indentation defines the code block under each condition.

# %%
i = 20
# Checking if i is greater than 15
if i > 15:
    print("20 is greater than 15")
# Out:
# 20 is greater than 15

# %% [markdown]
# Let’s understand the above code.
#
# The program first checks if the i is greater than 20. If true, it prints “20 is greater than 15.”
#
# * Conditions use comparison operators (==, !=, >, <, >=, <=) and logical operators (and, or, not)   to combine multiple conditions.
# * Indentation defines the code block under each condition.

# %% [markdown]
# **if....else Statement**
#
# <code>if...else statement</code> is a <code>control statement</code> that helps in <code>decision-making</code> based on specific <code>conditions</code>. When the <code>if condition</code> is <code>False</code>. If the <code>condition</code> in the <code>if statement</code> is not <code>true</code>, the **else block** will be executed.

# %%
i = 20

# Checking if i is greater than 0
if i > 30:
    print("i is greater than 30")
else:
    print("i is less than 30")
# Out:
# i is less than 30

# %% [markdown]
# Let’s understand the above code.
#
# The program first checks if the i is greater than 30. If true, it prints “i is greater than 30.”
# If not, it checks if the i is less than 30. If false, it prints “i is less than 30”
#
# * Conditions use comparison operators (==, !=, >, <, >=, <=) and logical operators (and, or, not)   to combine multiple conditions.
# * Indentation defines the code block under each condition.

# %%
x = False

if x:
    print('x was True!')
else:
    print('I will be printed in any case where x is not true')
# Out:
# I will be printed in any case where x is not true

# %% [markdown]
# ### Multiple Branches
#
# The <code>“ if ” </code>statement checks a <code>condition</code> and if it evaluates to <code>True</code> executes the <code>indented code block</code>. <code>elif</code> (short for "else if") and <code>else</code> provide alternative <code>code blocks</code> to run if the initial condition is <code>False.</code>
# We'll reintroduce a comparison syntax for Python.

# %%
score = 75

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
# Out:
# Grade: B

# %%
a= 20
b= 30

if a == b:
    print("a is equal to b")
elif a != b:
    print("a is not equal to b")
elif a > b:
    print("a is greater than b")
elif a < b:
    print("a is less than b")
elif a >= b:
    print("a is greater than or equal to b")
elif a<= b:
    print("a is less than or equal to b")
else:
    print("print a and b")
# Out:
# a is not equal to b

# %%
location = 'Bank'

if location == 'Auto Shop':
    print('Welcome to the Auto Shop!')
elif location == 'Bank':
    print('Welcome to the bank!')
else:
    print('Where are you?')
# Out:
# Welcome to the bank!

# %% [markdown]
# Note how the nested <code>if</code> statements are each checked until a True boolean causes the nested code below it to run. You should also note that you can put in as many <code>elif</code> statements as you want before you close off with an <code>else</code>.
#
# Let's create two more simple examples for the <code>if</code>, <code>elif</code>, and <code>else</code> statements:

# %%
person = 'Talal'

if person == 'Talal':
    print('Welcome Talal!')
# Out:
# Welcome Talal!

# %%
person = 'Talal'

if person == 'Talal':
    print('Welcome Talal!')
else:
    print("Welcome, what's your name?")
# Out:
# Welcome Talal!

# %%
person = 'Maheen'

if person == 'Talal':
    print('Welcome Talal!')
elif person =='Maheen':
    print('Welcome Maheen!')
else:
    print("Welcome, what's your name?")
# Out:
# Welcome Maheen!

# %% [markdown]
# ### Write a Python program that asks the user to input an integer. The program should check whether the number is even or odd and display the result.

# %%
number = int(input("Write the value of a ")) 
if number % 2 == 0: 
    print("number is even ") 
else: 
    print("num is odd ")
# Out:
# Write the value of a 8
# number is even

# %% [markdown]
# ### write a program that gets three subject marks and displays their average. It congratulates the user if the average is greater than high score i.e. 95 otherwise displays better luck next time.

# %%
sub1 = float(input("Enter marks of subject 1: "))
sub2 = float(input("Enter marks of subject 2: "))
sub3 = float(input("Enter marks of subject 3: "))

average = (sub1 + sub2 + sub3) / 3

if average > 95:
    print("Congratulations!")
else:
    print("Better luck next time.")
# Out:
# Enter marks of subject 1: 40
# Enter marks of subject 2: 30
# Enter marks of subject 3: 25
# Better luck next time.

# %% [markdown]
# ### Chris owns an auto repair business and has several employees. If any employee works over 40 hours in a week, he pays them 1.5 times their regular hourly pay rate for all hours over 40. He has asked you to design a simple payroll program that calculates an employee’s gross pay, including any overtime wages.
# ### If the employee worked more than 40 hours:
# ### Calculate and display the gross pay with overtime.
# ### Else:
# ### Calculate and display the gross pay as usual.

# %%
base_hours=40
hours =float (input ("Enter the number of hours of Employee: "))
pay_rate=float (input("Enter the hourly pay rate: "))
if hours > base_hours:
    overtime_hours=hours - base_hours
    overtime_pay=overtime_hours * pay_rate * 1.5
    gross_pay=(base_hours * pay_rate) + overtime_pay
else:
    gross_pay=hours * pay_rate

print(gross_pay)
# Out:
# Enter the number of hours of Employee 60
# Enter the hourly pay rate 500
# 35000.0

# %% [markdown]
# #### Flowchart Symbols for Flowchart Diagrams

# %%
display(Image(filename="DataFlowNotation.jpg"))

# %% [markdown]
# ## Indentation
#
# It is important to keep a good understanding of how indentation works in Python to maintain the structure and order of your code. We will touch on this topic again when we start building out functions!
