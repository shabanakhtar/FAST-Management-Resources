# %% [markdown]
# # Strings

# %% [markdown]
# Strings are used in Python to record text information, such as names. Strings in Python are actually a *sequence*, which basically means Python keeps track of every element in the string as a sequence. For example, Python understands the string "hello' to be a sequence of letters in a specific order. This means we will be able to use indexing to grab particular letters (like the first letter, or the last letter).
#
# This idea of a sequence is an important one in Python and we will touch upon it later on in the future.
#
# In this lecture we'll learn about the following:
#
#     1.) Creating Strings
#     2.) Printing Strings
#     3.) String Indexing and Slicing
#     4.) String Properties
#     5.) String Methods
#     6.) Print Formatting

# %% [markdown]
# ## Creating a String
# To create a string in Python you need to use either <code>single quotes or double quotes</code>. For example:

# %%
# Single word
'hello'
# Out:
# 'hello'

# %%
# Entire phrase 
'This is also a string'
# Out:
# 'This is also a string'

# %%
# We can also use double quote
"String built with double quotes"
# Out:
# 'String built with double quotes'

# %%
# Be careful with quotes!
' I' m using single quotes, but this will create an error'
# Out:
#   File "C:\Users\Aayat\AppData\Local\Temp\ipykernel_10780\2053197537.py", line 2
#     ' I'm using single quotes, but this will create an error'
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# The reason for the error above is because the single quote in <code>**I'm**</code> stopped the string. You can use combinations of double and single quotes to get the complete statement.

# %%
"Now I'm ready to use the single quotes inside a string!"
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %% [markdown]
# Now let's learn about printing strings!

# %% [markdown]
# ## Printing a String
#
# Using Jupyter notebook with just a string in a cell will automatically output strings, but the correct way to display strings in your output is by using a print function.

# %%
# We can simply declare a string
'Hello World'
# Out:
# 'Hello World'

# %%
# Note that we can't output multiple strings this way
'Hello World 1'
'Hello World 2'
# Out:
# 'Hello World 2'

# %% [markdown]
# We can use a print statement to print a string.

# %%
print('Hello World 1')
print('Hello World 2')
print('Use \n to print a new line')
print('\n')
print('See what I mean?')
# Out:
# Hello World 1
# Hello World 2
# Use
#  to print a new line
#
#
# See what I mean?

# %% [markdown]
# ## String Basics

# %% [markdown]
# We can also use a function called len() to check the length of a string!

# %%
#len("Hello")
len('Hello World')
# Out:
# 11

# %% [markdown]
# Python's built-in **len() function** counts all of the characters in the string, including spaces and punctuation.

# %% [markdown]
# ## String Indexing
# We know strings are a sequence, which means Python can use indexes to call parts of the sequence. Let's learn how this works.
#
# In Python, we use brackets <code>**[]**</code> after an object to call its index. We should also note that indexing starts at 0 for Python. Let's create a new object called <code>s</code> and then walk through a few examples of indexing.

# %%
# Assign s as a string
s = "Hello World"

# %%
#Check
s
# Out:
# 'Hello World'

# %%
# Print the object
print(s)
type(s)
# Out:
# Hello World
# str

# %% [markdown]
# Let's start indexing!

# %%
from IPython.display import Image

# %%
Image(filename="StringIndex.png")

# %%
# Show first element (in this case a letter)
#variableName[1]

s[0]
# Out:
# 'H'

# %%
s[1]
# Out:
# 'e'

# %%
s[2]
# Out:
# 'l'

# %% [markdown]
# We can use a <code>:</code> to perform **slicing** which grabs everything up to a designated point. For example:
#
# You can return a range of characters by using the slice syntax.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
# Grab everything past the first term all the way to the length of s which is len(s)
#variableName[start:end]

s[:]
# Out:
# 'Hello'

# %%
# Note that there is no change to the original s
s
# Out:
# 'Hello World'

# %%
# Grab everything UP TO the 3rd index
# 0,1,2,3 ex.

s[:3]
# Out:
# 'Hel'

# %% [markdown]
# Note the above slicing. Here we're telling Python to grab everything from 0 up to 3. It doesn't include the 3rd index. You'll notice this a lot in Python, where statements and are usually in the context of "up to, but not including".

# %%
#Everything
s[:]
# Out:
# 'Hello World'

# %% [markdown]
# We can also use negative indexing to go backwards.

# %%
# Last letter (one index behind 0 so it loops back around)
s[-3]
# Out:
# 'r'

# %%
# Grab everything but the last letter ex.
s[:-1]
# Out:
# 'Hello Worl'

# %% [markdown]
# We can also use index and slice notation to grab elements of a sequence by a specified step size (the default is 1). For instance we can use two colons in a row and then a number specifying the frequency to grab elements. For example:

# %%
# s[start:end:step]
s[0:11]
# Out:
# 'Hello World'

# %%
# Grab everything, but go in steps size of 1
s[::1]
# Out:
# 'Hello World'

# %%
# Grab everything, but go in step sizes of 2
s[::2]
# Out:
# 'HloWrd'

# %%
#s2 = "abcd efg hijk"
s1 = "Hello World"
count = 0
for letter in s1:
    print(f"{count}  {letter}")
    count = count + 1
    
#len("abcd efg hijk")
len("Hello World")
# Out:
# 0  H
# 1  e
# 2  l
# 3  l
# 4  o
# 5
# 6  W
# 7  o
# 8  r
# 9  l
# 10  d
# 11

# %%
s2[::2]
# Out:
# 'ac f ih'

# %%
# We can use this to print a string backwards
s[::-1]
# Out:
# 'dlroW olleH'

# %% [markdown]
# ## String Properties
# It's important to note that strings have an important property known as <code>*immutability*</code>. This means that once a string is created, the elements within it can not be changed or replaced. For example:

# %%
s
# Out:
# 'Hello World'

# %%
s[0]
# Out:
# 'H'

# %%
# Let's try to change the first letter to 'x'
s[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5644\2138848189.py in <module>
#       1 # Let's try to change the first letter to 'x'
# ----> 2 s[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Notice how the error tells us directly what we can't do, change the item assignment!
#
# Something we *can* do is concatenate strings!

# %%
s
# Out:
# 'Hello World'

# %%
# Concatenate strings!
s
# Out:
# 'Hello World'

# %%
# We can reassign s completely though!
s + ' concatenate me!'
# Out:
# 'Hello World concatenate me!'

# %%
print(s)
# Out:
# Hello World

# %%
s = s + ' concatenate me!'

# %%
s
# Out:
# 'Hello World concatenate me!'

# %% [markdown]
# We can use the multiplication symbol to create repetition!

# %%
letter = 'z'

# %%
letter
# Out:
# 'z'

# %%
letter*10
# Out:
# 'zzzzzzzzzz'

# %%
print(letter)
# Out:
# z

# %% [markdown]
# ## Basic Built-in String methods
#
# Objects in Python usually have built-in methods. These methods are functions inside the object (we will learn about these in much more depth later) that can perform actions or commands on the object itself.
#
# We call methods with a period and then the method name. Methods are in the form:
#
# object.method(parameters)
#
# Where parameters are extra arguments we can pass into the method. Don't worry if the details don't make 100% sense right now. Later on we will be creating our own objects and functions!
#
# Here are some examples of built-in methods in strings:

# %%
s
# Out:
# 'Hello World concatenate me!'

# %%
# Upper Case a string
# str.upper()
s.upper()
# Out:
# 'HELLO WORLD CONCATENATE ME!'

# %%
# Lower case
s.lower()
# Out:
# 'hello world concatenate me!'

# %%
# Split a string by blank space (this is the default)
#  [1,2,3,4,"ali",2.5]
s
s.split()
# Out:
# ['Hello', 'World', 'concatenate', 'me!']

# %%
# Split by a specific element (doesn't include the element that was split on)
s.split('W')
# Out:
# ['Hello ', 'orld concatenate me!']

# %%
# The strip() method removes any leading, and trailing whitespaces.
# Leading means at the beginning of the string, trailing means at the end.

"a" == "a " 
txt = " mango "
txt
txt = txt.strip()  # left or right trim
txt
# Out:
# 'mango'

# %% [markdown]
# ## Print Formatting
#
# We can use the .format() method to add formatted objects to printed string statements.
#
# The easiest way to show this is through an example:

# %%
print('Insert another string with curly brackets: {}'.format('The inserted string'))
# Out:
# Insert another string with curly brackets: The inserted string

# %%
parameter = 'The parameter value'

f'Insert another string with curly brackets: {parameter}'
print(f'Insert another string with curly brackets: {parameter}')
# Out:
# Insert another string with curly brackets: The parameter value

# %% [markdown]
# #### This program demonstrates how to tokenize strings.

# %%
# Simple Ways to Tokenize Text in Python

str1 = "one two three four"
str2 = "10:20:30:40"
str3 = "21/02/2026"

# Display the tokens in each string
#token1 = str1.split(" ")
#token1

#token2 = str2.split(":")
#token2

token3 = str3.split("/")
print(token3)
# Out:
# ['21', '02', '2026']

# %% [markdown]
# ## Next up: Lists!
