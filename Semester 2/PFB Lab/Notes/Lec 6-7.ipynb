# %% [markdown]
# # Functions
#
# ## A function is a group of statements that exist within a program for the purpose of performing a specific task. This approach is sometimes called divide and conquer because a large task is divided into several smaller tasks that are easily performed. A program that has been written with each task in its own function is called a modularized program.

# %% [markdown]
# ![Screenshot%202025-10-22%20155026.png](attachment:Screenshot%202025-10-22%20155026.png)

# %% [markdown]
# # Benefits of Modularizing a Program with Functions

# %% [markdown]
# # Simpler Code
# # Code Reuse
# # Faster Development

# %% [markdown]
# # Void Functions and Value-Returning Functions

# %% [markdown]
# #  two types of functions: void functions and value returning functions.
# # When you call a void function, it simply executes the statements it contains and then terminates.
# # When you call a value-returning function, it executes the statements that it contains, then returns a value back to the statement that called it.

# %% [markdown]
# # Defining and Calling a Void Function

# %% [markdown]
# # Function Names

# %% [markdown]
# * You cannot use one of Python’s keywords as a function name.
# * A function name cannot contain spaces.
# * The first character must be one of the letters a through z, A through Z, or an under￾score character (_).
# * After the first character you may use the letters a through z or A through Z, the digits 0 through 9, or underscores.
# * Uppercase and lowercase characters are distinct.

# %% [markdown]
# # Because functions perform actions, most programmers prefer to use verbs in function names.
# # Each function name should describe what the function does.

# %% [markdown]
# # Syntax
#
# # def function_name():
# #      statement
# #      statement
# #      etc.

# %%
# First we define a function named message
def message():
    print('I am Arthur,')
    print('King of the Britons.')

# %% [markdown]
# # (Remember, a function definition creates a function, but it does not call the function to execute.)

# %% [markdown]
# # How control works

# %%
message()
# Out:
# I am Arthur,
# King of the Britons.

# %%
def greeting(name):
    return (f'Hello {name}')

# %%
greeting("Muhammad")
# Out:
# 'Hello Muhammad'

# %%
def main():
    print('I have a message for you.')
    message() #call a function
    print('Goodbye!')

# %%
# Call the main function.
main()
# Out:
# I have a message for you.
# I am Arthur,
# King of the Britons.
# Goodbye!

# %% [markdown]
# # Top-Down Design
#
# # We use a technique known as top-down design to break down an algorithm into functions. The process of top-down design is performed in the following manner:
# * The overall task that the program is to perform is broken down into a series of subtasks.
# * Each of the subtasks is examined to determine whether it can be further broken down into more subtasks. This step is repeated until no more subtasks can be identified.
# * Once all of the subtasks have been identified, they are written in code.

# %% [markdown]
# # Hierarchy Charts

# %% [markdown]
# ![heirarchy.png](attachment:heirarchy.png)

# %% [markdown]
# # Local Variables

# %% [markdown]
# # A local variable is created inside a function and cannot be accessed by statements that are outside the function. Different functions can have local variables with the same names because the functions cannot see each other's local variables.Anytime you assign a value to a variable inside a function, you create a local variable.

# %%
def get_name():
    name = input('Enter your name: ')

# %%
get_name()
# Out:
# Enter your name: K

# %%
def main():
    get_name()
    print(f'Hello {name}.') # This causes an error!
# Definition of the get_name function.
def get_name():
    name = input('Enter your name: ')

# %%
main()
# Out:
# Enter your name: ali
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21264\451043146.py in <module>
# ----> 1 main()
#
# ~\AppData\Local\Temp\ipykernel_21264\2479486570.py in main()
#       1 def main():
#       2     get_name()
# ----> 3     print(f'Hello {name}.') # This causes an error!
#       4 # Definition of the get_name function.
#       5 def get_name():
#
# NameError: name 'name' is not defined

# %% [markdown]
# # Scope and Local Variables

# %% [markdown]
# # A variable’s scope is the part of a program in which the variable may be accessed. A variable is visible only to statements in the variable’s scope. A local variable’s scope is the function in which the variable is created. No statement outside the function may access the variable.

# %% [markdown]
# # a local variable cannot be accessed by code that appears inside the function at a point before the variable has been created. For example, look at the following function. It will cause an error because the print function tries to access the val variable, but this statement appears before the val variable has been created. Moving the assignment statement to a line before the print statement will fix this error.

# %%
def bad_function():
    val = 99
    print(f'The value is {val}.') # This will cause an error!

# %%
bad_function()
# Out:
# The value is 99.

# %% [markdown]
# # Because a function’s local variables are hidden from other functions, the other functions may have their own local variables with the same name

# %%
def texas():
    birds = 5000
    print(f'texas has {birds} birds.')

# %%
texas()
# Out:
# texas has 5000 birds.

# %%
def california():
    birds = 8000
    print(f'california has {birds} birds.')

# %%
california()
# Out:
# california has 8000 birds.

# %%
def main():
# Call the texas function.
    texas()
# Call the california function.
    california()

# Definition of the texas function. It creates
# a local variable named birds.
def texas():
    birds = 5000
    print(f'texas has {birds} birds.')
# Definition of the california function. It also
# creates a local variable named birds.
def california():
    birds = 8000
    print(f'california has {birds} birds.')

# %%
main()
# Out:
# texas has 5000 birds.
# california has 8000 birds.

# %% [markdown]
# # Passing Arguments to Functions

# %% [markdown]
# # An argument is any piece of data that is passed into a function when the function is called. A parameter is a variable that receives an argument that is passed into a function.

# %% [markdown]
# # Parameters = what the function expects
# # Arguments = what the function gets

# %%
def show_double(number): # number is the parameter.It appears in the function definition.It acts as a placeholder variable that will hold the value passed to the function.
    result = number * 2
    print(result)

# %%
show_double(3) # 2 is the argument.It appears in the function call. It is the actual value given to the parameter number.
# Out:
# 6

# %%
def main():
    value = 5
    show_double(value) # argument

# The show_double function accepts an argument
# and displays double its value.
def show_double(number): # parameter
    result = number * 2
    print(result)

# %%
# Call the main function.
main()
# Out:
# 10

# %% [markdown]
# ![argument.png](attachment:argument.png)

# %% [markdown]
# # Parameter Variable Scope
# # You learned that a variable’s scope is the part of the program in which the variable may be accessed. A variable is visible only to statements inside the variable’s scope. A parameter variable’s scope is the function in which the parameter is used. All of the statements inside the function can access the parameter variable, but no statement outside the function can access it.

# %%
def show_double(number):  # 'number' is a parameter variable
    result = number * 2   # Accessible here
    print(result)

show_double(5)  # argument Output: 10
print(number)   # ❌ Error — 'number' not defined here
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21264\786282086.py in <module>
#       4
#       5 show_double(5)  # argument Output: 10
# ----> 6 print(number)   # ❌ Error — 'number' not defined here
#
# NameError: name 'number' is not defined

# %%
def intro():
    print('This program converts measurements')
    print('in cups to fluid ounces. For your')
    print('reference the formula is:')
    print(' 1 cup = 8 fluid ounces')
    print()

# %%
intro()
# Out:
# This program converts measurements
# in cups to fluid ounces. For your
# reference the formula is:
#  1 cup = 8 fluid ounces

# %%
def cups_to_ounces(cups):
    ounces = cups * 8
    print(f'That converts to {ounces} ounces.')

# %%
cups_to_ounces(2)
# Out:
# That converts to 16 ounces.

# %%
def main():
# display the intro screen.
    intro()
# Get the number of cups.
    cups_needed = int(input('Enter the number of cups: '))
# Convert the cups to ounces.
    cups_to_ounces(cups_needed)
# The intro function displays an introductory screen.

 
def intro():
    print('This program converts measurements')
    print('in cups to fluid ounces. For your')
    print('reference the formula is:')
    print(' 1 cup = 8 fluid ounces')
    print()

# The cups_to_ounces function accepts a number of
# cups and displays the equivalent number of ounces.

 
def cups_to_ounces(cups):
    ounces = cups * 8
    print(f'That converts to {ounces} ounces.')

# %%
# Call the main function.
main()
# Out:
# This program converts measurements
# in cups to fluid ounces. For your
# reference the formula is:
#  1 cup = 8 fluid ounces
#
# Enter the number of cups:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21264\1263540007.py in <module>
#       1 # Call the main function.
# ----> 2 main()
#
# ~\AppData\Local\Temp\ipykernel_21264\2483710139.py in main()
#       3     intro()
#       4 # Get the number of cups.
# ----> 5     cups_needed = int(input('Enter the number of cups: '))
#       6 # Convert the cups to ounces.
#       7     cups_to_ounces(cups_needed)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# # Passing Multiple Arguments

# %%
# The show_sum function accepts two arguments
# and displays their sum.
def show_sum(num1, num2):
    result = num1 + num2
    #print(result)
    return result

# %%
#show_sum(2, 2)
add_numbers = show_sum(2, 2)
print(add_numbers)
# Out:
# 4

# %%
# The show_sum function accepts two arguments
# and displays their sum.
def show_sum(num1, num2):
    result = num1 + num2
    print(result)

# %%
def main():
    print('The sum of 12 and 45 is')
    show_sum(12, 45)

# Call the main function.
main()
# Out:
# The sum of 12 and 45 is
# 57

# %% [markdown]
# # Making Changes to Parameters

# %% [markdown]
# # When an argument is passed to a function in Python, the function parameter variable will reference the argument’s value. However, any changes that are made to the parameter variable will not affect the argument.

# %%
def change_me(arg):
    print("Value passed is", arg)
    print('I am changing the value.')
    arg = 0
    print(f'Now the value is {arg}.')

# %%
def main():
    value = 99
    print(f'The value is {value}.')
    change_me(value)
    print(f'Back in main the value is {value}.')

# %%
# Call the main function.
main()
# Out:
# The value is 99.
# Value passed is 99
# I am changing the value.
# Now the value is 0.
# Back in main the value is 99.

# %% [markdown]
# # Keyword Arguments
# # Lets demonstrate how arguments are passed by position to parameter variables in a function. Most programming languages match function arguments and parameters this way. In addition to this conventional form of argument passing, the Python language allows you to write an argument in the following format, to specify which parameter variable the argument should be passed to:
# # parameter_name=value
#
# # Keyword arguments are arguments passed by explicitly naming the parameter in the function call.
#
# # In this format, parameter_name is the name of a parameter variable, and value is the value being passed to that parameter. An argument that is written in accordance with this syntax is known as a keyword argument.
# # This program uses a function named show_interest that displays the amount of simple interest earned by a bank account for a number of periods. The function accepts the arguments principal (for the account principal), rate (for the interest rate per period), and periods (for the number of periods). When the function is called, the arguments are passed as keyword arguments.

# %%
def main():
# Show the amount of simple interest, using 0.01 as
# interest rate per period, 10 as the number of periods,
# and $10,000 as the principal.
    show_interest(rate=0.01, periods=10, principal=10000.0)
# The show_interest function displays the amount of
# simple interest for a given principal, interest rate
# per period, and number of periods.
def show_interest(principal, rate, periods):
    interest = principal * rate * periods
    print(f'The simple interest will be ${interest:,.2f}.')

# %%
# Call the main function.
main()
# Out:
# The simple interest will be $1,000.00.

# %% [markdown]
# # Mixing Keyword Arguments with Positional Arguments

# %% [markdown]
# # It is possible to mix positional arguments and keyword arguments in a function call, but the positional arguments must appear first, followed by the keyword arguments. Otherwise, an error will occur. Here is an example of how we might call the show_interest function using both positional and keyword arguments:
# # show_interest(10000.0, rate=0.01, periods=10)
# # In this statement, the first argument, 10000.0, is passed by its position to the principal parameter. The second and third arguments are passed as keyword arguments. The following function call will cause an error, however, because a non-keyword argument follows a keyword argument:
# # This will cause an ERROR!
# # show_interest(1000.0, rate=0.01, 10)
#
# # You can mix positional and keyword arguments, but positional arguments must always come first in the function call.

# %%
def main():
    # Show the amount of simple interest
    show_interest(rate=0.01, periods=10, principal=10000.0)

def show_interest(principal, rate, periods):
    interest = principal * rate * periods
    print(f'The simple interest will be ${interest:,.2f}.')

# %%
main()
# Out:
# The simple interest will be $1,000.00.

# %% [markdown]
# # Case 1 – All keyword arguments (Correct)

# %%
show_interest(rate=0.01, periods=10, principal=10000.0)
# Out:
# The simple interest will be $1,000.00.

# %% [markdown]
# # Case 2 – All positional arguments (Correct)

# %%
show_interest(10000.0, 0.01, 10)
# Out:
# The simple interest will be $1,000.00.

# %% [markdown]
# # Case 3 – Mix of positional and keyword arguments (Correct)

# %%
show_interest(10000.0, rate=0.01, periods=10)
# Out:
# The simple interest will be $1,000.00.

# %% [markdown]
# # Works because positional comes first, then keyword.

# %% [markdown]
# # Case 4 – Keyword followed by positional (Error)

# %%
show_interest(rate=0.01, 10000.0, periods=10)
# Out:
#   File "<ipython-input-27-21de256a6dba>", line 1
#     show_interest(rate=0.01, 10000.0, periods=10)
#                              ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# # After starting with a keyword argument (rate=0.01),you provided a positional argument (10000.0) — which is not allowed.
#
# # Python doesn’t know which parameter to assign that value to after keyword arguments have begun.

# %% [markdown]
# # Global Variables and Global Constants
#
# ## A global variable is accessible to all the functions in a program file. When a variable is created by an assignment statement that is written outside all the functions in a program file, the variable is global.

# %%
my_value = 10

# The show_value function prints
# the value of the global variable.
def show_value():
    print(my_value)
    
def new_value():
    return my_value

# Call the show_value function.
show_value()
new_value()
# Out:
# 10
# 10

# %% [markdown]
# # An additional step is required if you want a statement in a function to assign a value to a global variable. In the function, you must declare the global variable

# %%
# Create a global variable.
number = 0
def main():
    global number
    number = int(input('Enter a number: '))
    show_number()
def show_number():
    print(f'The number you entered is {number}.')

# %%
# Call the main function.
main()
# Out:
# Enter a number: 10
# The number you entered is 10.

# %% [markdown]
# # Global Constants

# %%
# The following is used as a global constant to represent
# the contribution rate.
CONTRIBUTION_RATE = 0.05
def main():
    gross_pay = float(input('Enter the gross pay: '))
    bonus = float(input('Enter the amount of bonuses: '))
    show_pay_contrib(gross_pay)
    show_bonus_contrib(bonus)
# The show_pay_contrib function accepts the gross
# pay as an argument and displays the retirement
# contribution for that amount of pay.
 
def show_pay_contrib(gross):
    contrib = gross * CONTRIBUTION_RATE
    print(f'Contribution for gross pay: ${contrib:,.2f}.') 
# The show_bonus_contrib function accepts the
# bonus amount as an argument and displays the
# retirement contribution for that amount of pay.
 
def show_bonus_contrib(bonus):
    contrib = bonus * CONTRIBUTION_RATE
    print(f'Contribution for bonuses: ${contrib:,.2f}.')

# %%
main()
# Out:
# Enter the gross pay: 4300
# Enter the amount of bonuses: 340
# Contribution for gross pay: $215.00.
# Contribution for bonuses: $17.00.

# %% [markdown]
# # Definition of global variable:	A variable declared at the top level of a script or module whose value can change during program execution.
# # Definition of global constant: A variable declared at the top level of a script or module whose value is intended to remain constant throughout the program.
#
# # Naming Convention for global variable: 	Written in lowercase_with_underscores.
# # Naming Convention for global constant: Written in ALL_CAPS with underscores to indicate it should not be changed.
# # Example of global variable	counter = 0
# # Example of global constant  PI = 3.14159
# # Changeability of global variable	Can be reassigned inside functions (using the global keyword).
# # Changeability of global constant: Should not be reassigned — but Python does not prevent it. This is by convention only.
# # use of global variable : Used for values that may change (e.g., program state, counters).
# # use of global constant: Used for fixed values that define configuration or reference values (e.g., mathematical constants, file paths).

# %% [markdown]
# # Value-Returning Functions
# ## A value-returning function is a function that returns a value back to the part of the program that called it.
#
# ## You write a value-returning function in the same way that you write a void function, with one exception: a value-returning function must have a return statement.

# %% [markdown]
# # def function_name():
#
# #     statement
# #     statement
# #     etc.
# #     return expression

# %% [markdown]
# # The value of the expression that follows the keyword return will be sent back to the part of the program that called the function

# %%
def main():
# Get the user's age.
    first_age = int(input('Enter your age: '))
# Get the user's best friend's age.
    second_age = int(input("Enter your best friend's age: "))

# Get the sum of both ages.
    total = total_of_ages(first_age, second_age)
# Display the total age.
    print(f'Together you are {total} years old.')
# The sum function accepts two numeric arguments and
# returns the sum of those arguments.
def total_of_ages(num1, num2):
    result = num1 + num2
    return result

# %%
main()
# Out:
# Enter your age: 10
# Enter your best friend's age: 15
# Together you are 25 years old.

# %% [markdown]
# # Using Value-Returning Functions

# %%
# This program calculates a retail item's sale price.
# DISCOUNT_PERCENTAGE is used as a global constant for the discount percentage.
DISCOUNT_PERCENTAGE = 0.20
# The main function.
def main():
# Get the item's regular price.
    reg_price = get_regular_price()

# Calculate the sale price.
    sale_price = reg_price - discount(reg_price)
# Display the sale price.
    print(f'The sale price is ${sale_price:,.2f}.')

# The get_regular_price function prompts the user to enter an item's regular price and it returns that value.
def get_regular_price():
    price = float(input("Enter the item's regular price: "))
    return price
# The discount function accepts an item's price as an argument and returns the amount of the discount, specified by 
# DISCOUNT_PERCENTAGE.
def discount(price):
    return price * DISCOUNT_PERCENTAGE

# %%
main()
# Out:
# Enter the item's regular price: 230
# The sale price is $184.00.

# %% [markdown]
# # Returning Strings

# %%
def get_name():
    # Get the user's name.
    name = input('Enter your name: ')
    # Return the name.
    return name

# %%
get_name()
# Out:
# Enter your name: nida
# 'nida'

# %% [markdown]
# # Returning Boolean Values
# ## Boolean functions, which return either True or False. You can use a Boolean function to test a condition, then return either True or False to indicate whether the condition exists. Boolean functions are useful for simplifying complex conditions that are tested in decision and repetition structures

# %%
def is_even(number):
 # Determine whether number is even. If it is,
 # set status to true. Otherwise, set status
 # to false.
    if (number % 2) == 0:
        status = True
    else:
        status = False
 # Return the value of the status variable.
    return status

# %%
number = int(input('Enter a number: '))
if is_even(number):
    print('The number is even.')
else:
    print('The number is odd.')
# Out:
# Enter a number: 10
# The number is even.

# %%
string = "ABCd"

# %%
count = 0
for letter in string:
    print(letter)
    if letter.isupper():
        count = count + 1
        
print(count)
# Out:
# A
# B
# C
# d
# 3

# %%
string.isupper()
# Out:
# True

# %% [markdown]
# # Returning Multiple Values

# %% [markdown]
# # return expression1, expression2, etc.

# %%
def get_name():
 # Get the user's first and last names.
    first = input('Enter your first name: ')
    last = input('Enter your last name: ')
 # Return both names.
    return (first, last)

# %%
print(get_name('tayyab', 'shah'))
# Out:
# Enter your first name: shah
# Enter your last name: tayyab
# ('shah', 'tayyab')

# %%
my_list = [1,2,3,4,5]

# %%
emp_list = []
addition = 0
for num in my_list:
    addition = addition + num
    
print(addition)
# Out:
# 15

# %%
len(my_list)
# Out:
# 5
