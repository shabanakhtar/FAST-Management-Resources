# %% [markdown]
# ___
#
# <a href='https://lhr.nu.edu.pk/'><img src='../FastUniversityLahore.png'/></a>
# ___
# <center><em>Fast School of Management</em></center>

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# This is test line :
# Ctrl+Enter,Shift+Enter, Alt+Enter, Shift+L

# %% [markdown]
# # Data Types

# %% [markdown]
# * Integer
# * float
# * String

# %%
3+5
# Out:
# 8

# %%
print(type(3+5))

# %%
2*3

# %%
2**3

# %%
5/2

# %%
4%2

# %%
2.5+2.5

# %%
print(type(2.5+2.5))

# %%
2.5*2.5

# %%
"a"

# %%
"Hello world"

# %%
print(type("Hello world"))

# %% [markdown]
# # Variable

# %% [markdown]
# # Rules for naming variables
# * no space in variable name used _
# * names can not start with a number
# * first letter should be a to z or _NameOfVariable
# * uppercase and lowercase are different
# * keyword can't be named as variable (sum, list, str)
# * name should reflect the indication of what they are used for
# * names can not contain any of these symbols:
#
#       :'",<>/?|\!@#%^&*~-+
#
# * it's considered best practice ([PEP8](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names))

# %% [markdown]
# Python uses dynamic typing, meaning you can reassign variables to different data types. This makes Python very flexible in assigning data types; it differs from other languages that are statically typed.

# %% [markdown]
# ### Declare four variables i.e. name, age, gender and weight

# %% [markdown]
# A single equals sign = is an assignment operator

# %%
print(Bilal)

# %%
name="Bilal"
age=16
gender="male"
weight=52.5

# %%
print(name)
print(age)
print(gender)
print(weight)

# %%
print("My age is", age)

# %%
# My name is Bilal
# My weight is 52.5

# %% [markdown]
# ### Assign the value 50 to Length and 30 to width of rectangle and print

# %%
length=50
width=30

# %%
print("length of square is ", length)

# %%
print("Width of square is", width)

# %%
print("Length and width of square is ", length, "and", width, "respectively.")

# %% [markdown]
# # String Formatting
#
# String formatting lets you inject items into a string rather than trying to chain items together using commas or string concatenation. As a quick comparison, consider:
#
#     player = 'Thomas'
#     points = 33
#
#     'Last night, '+player+' scored '+str(points)+' points.'  # concatenation
#
#     f'Last night, {player} scored {points} points.'          # string formatting
#
#
# There are three ways to perform string formatting.
# * The oldest method involves placeholders using the modulo `%` character.
# * An improved technique uses the `.format()` string method.
# * The newest method, introduced with Python 3.6, uses formatted string literals, called *f-strings*.
#
# Since you will likely encounter all three versions in someone else's code, we describe each of them here.

# %% [markdown]
# ### Formatting with the `.format()` method
# A better way to format objects into your strings for print statements is with the string `.format()` method. The syntax is:
#
#     'String here {} then also {}'.format('something1','something2')
#
# For example:

# %%
print('This is a string with an {}'.format('insert'))

# %%
print("Length and width of square is {} and {} respectively.".format(length,width))

# %% [markdown]
# ### The .format() method has several advantages

# %% [markdown]
# #### 1. Inserted objects can be called by index position:

# %%
print('The {2} {1} {0}'.format('fox','brown','quick'))

# %% [markdown]
# #### 2. Inserted objects can be assigned keywords:

# %%
print('First Object: {a}, Second Object: {b}, Third Object: {c}'.format(a=1,b='Two',c=12.3))

# %% [markdown]
# #### 3. Inserted objects can be reused, avoiding duplication:

# %%
print('A {p} saved is a {p} earned.'.format(p='penny'))

# %% [markdown]
# ### Alignment, padding and precision with `.format()`
# Within the curly braces you can assign field lengths, left/right alignments, rounding parameters and more

# %%
print('{0:8} | {1:9}'.format('Fruit', 'Quantity'))
print('{0:8} | {1:9}'.format('Apples', 3.))
print('{0:8} | {1:9}'.format('Oranges', 10))

# %% [markdown]
# By default, `.format()` aligns text to the left, numbers to the right. You can pass an optional `<`,`^`, or `>` to set a left, center or right alignment:

# %%
print('{0:<8} | {1:^8} | {2:>8}'.format('Left','Center','Right'))
print('{0:<8} | {1:^8} | {2:>8}'.format(11,22,33))

# %% [markdown]
# You can precede the aligment operator with a padding character

# %%
print('{0:=<8} | {1:-^8} | {2:.>8}'.format('Left','Center','Right'))
print('{0:=<8} | {1:-^8} | {2:.>8}'.format(11,22,33))

# %% [markdown]
# Field widths and float precision are handled in a way similar to placeholders. The following two print statements are equivalent:

# %%
print('This is my ten-character, two-decimal number:%10.2f' %13.579)
print('This is my ten-character, two-decimal number:{0:10.2f}'.format(13.579))

# %% [markdown]
# Note that there are 5 spaces following the colon, and 5 characters taken up by 13.58, for a total of ten characters.
#
# For more information on the string `.format()` method visit https://docs.python.org/3/library/string.html#formatstrings

# %% [markdown]
# ## Formatted String Literals (f-strings)
# #### Displaying Formatted Output with f-strings
# * An __f-string__ can contain placeholders for variables and other valid expressions.
# * Introduced in Python 3.6, f-strings offer several benefits over the older `.format()` string method described above. For one, you can bring outside variables immediately into to the string rather than pass them as arguments through `.format(var)`.

# %%
# Displaying Formatted Output with F-strings

print(f"Length and width of square is {length} and {width} respectively.")

# %%
name = 'Fred'

print(f"He said his name is {name}.")

# %% [markdown]
# Pass `!r` to get the string representation:

# %%
print(f"He said his name is {name!r}")

# %% [markdown]
# #### Float formatting follows `"result: {value:{width}.{precision}}"`

# %% [markdown]
# Where with the `.format()` method you might see `{value:10.4f}`, with f-strings this can become `{value:{10}.{6}}`

# %%
num = 23.45678
print("My 10 character, four decimal number is:{0:10.4f}".format(num))
# vs
print(f"My 10 character, four decimal number is:{num:{10}.{6}}")

# %% [markdown]
# Note that with f-strings, *precision* refers to the total number of digits, not just those following the decimal. This fits more closely with scientific notation and statistical analysis. Unfortunately, f-strings do not pad to the right of the decimal, even if precision allows it:

# %%
num =23.45
print("My 10 character, four decimal number is:{0:10.4f}".format(num))
print(f"My 10 character, four decimal number is:{num:{10}.{6}}")

# %% [markdown]
# If this becomes important, you can always use `.format()` method syntax inside an f-string:

# %%
num = 23.45
print("My 10 character, four decimal number is:{0:10.4f}".format(num))
print(f"My 10 character, four decimal number is:{num:10.4f}")

# %% [markdown]
# For more info on formatted string literals visit https://docs.python.org/3/reference/lexical_analysis.html#f-strings

# %% [markdown]
# # Variable Re-assignment

# %%
# print(length variable)\n
length=100
width=50
print(length, end=" ")
print(width)

# %%
# check the function defination
# print(click on Tab key)
length= 30
width=10
print(length,width, sep=" - ")

# %%
area=length+width
print("Area of rectangle", area)

# %%
a=5
print(a)

# %%
a=7
print(a)

# %%
z=2.5
print(z)

# %%
z=5.10
print(z)

# %%
y="fast"
print(y)

# %%
y="school"
print(y)

# %% [markdown]
# ## Determining variable type with `type()`
# You can check what type of object is assigned to a variable using Python's built-in `type()` function. Common data types include:
# * **int** (for integer)
# * **float**
# * **str** (for string)
# * **list**
# * **tuple**
# * **dict** (for dictionary)
# * **set**
# * **bool** (for Boolean True/False)

# %%
quantity=15
type(quantity)

# %%
price = 120.5
type(price)

# %%
f_name="Muhammad"
type(f_name)

# %% [markdown]
# ### Operators

# %% [markdown]
# * Arithmetic Operators
# * Assignment Operators
# * Comparison Operators
# * Logical Operators
# * Bitwise Operators

# %% [markdown]
# * Arithmetic Operators : Arithmetic operators are used with numeric values to perform common mathematical operations.

# %% [markdown]
# * find current working dictory (to place the image in this folder)

# %%
pwd

# %%
# Import the library for image to display(Interactive Python)
from IPython.display import Image

# %%
# Image(filename=r"path of file on your system")
# Note:replace 'jupyter notebook' and 'image files' in the same working folder
# follow to find current working folder use 'pwd'
Image(filename=r"C:\Users\Aayat\Operands.jpg")

# %%
x=25
y=5

print("x+y", x+y)

print("")
print("")

print("x-y", x-y)

print("")
print("")


print("x*y", x*y)

print("")
print("")


print("x/y", x/y) # division operator,and always returns a floating-point number.

print("")
print("")


print("x%y", x%y)

print("")
print("")


print("x//y",x//y) # Floor Division: operator performs division and rounds the result 
                   # down to the nearest integer.  
print("")
print("")

print("x**2",x**2)

# %%
7/3   # will give you a decimal number

# %%
8/4   # A floating point number

# %%
8//4  # will give you an integer value

# note : A // discards the decimal part of the answer

# %%
7//3   # The integer part of the result.
       # It is called floor division.

#   <--lowest +ve number
#      2.333
#  |---!-------|
#  2          3

# %%
7/3

# %%
-7/3

# %%
-7//3

#   <-- negative number
#          -2.333
#  |-------!---|
# -3           -2

# %% [markdown]
# * Assignment Operators : Assignment operators are used to assign values to variables.

# %% [markdown]
# There's actually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using `+=`, `-=`, `*=`, and `/=`.

# %%
# note: assigning 25 to variabl x.Value of x is 25
x=25

# %%
# note: Reassigning 25+1 to variable x.Now value of x is 26
x=x+1
print(x)
# Out:
# 26

# %%
# note: assigning 25 to variabl x.Value of x is 25
x=25

# %%
# note: Reassigning 25+1 to variable x.Now value of x is 26
# Both the Assigning method are same: x=x+1  x+=1
x+=1
print(x)
# Out:
# 26

# %%
x=25

x=x+5
print("x=x+5 --> x+=5",x)

print("")
print("")

x=x-5
print("x=x-5 --> x-=5",x)

print("")
print("")


x=x*5
print("x=x*5 --> x*=5",x)

print("")
print("")


x=x/5
print("x=x/5 --> x/=5",x)

# %% [markdown]
# * Comparison Operators :
# These operators will allow us to compare variables and output a Boolean value (True or False).

# %%
x=25
y=5

# %% [markdown]
# #### Equal  ==

# %%
x==y
# Out:
# False

# %% [markdown]
# Note that <code>==</code> is a <em>comparison</em> operator, while <code>=</code> is an <em>assignment</em> operator.

# %% [markdown]
# #### Not Equal   !=

# %%
# Logical NOT (!),  Bitwise complement (~)
x!=y
# Out:
# True

# %% [markdown]
# #### Greater Than   >

# %%
x>y
# Out:
# True

# %% [markdown]
# #### Less Than   <

# %%
x<y

# %% [markdown]
# #### Greater Than or Equal to   >=

# %%
x>=y

# %% [markdown]
# #### Less Than or Equal to   <=

# %%
x<=y

# %% [markdown]
# * Logical Operators : Logical operators are used to combine conditional statements.
# * AND
#
# * OR
#
# * NOT

# %%
x=25

# %% [markdown]
# #### and :Returns True if both statements are True

# %%
x > 5
# Out:
# True

# %%
x > 8
# Out:
# True

# %%
# Logical operators are used to 
# combine
# conditional statements(use above two conditional statements). 
x > 5 and x > 8
# Out:
# True

# %%
x > 5 and x < 50

# %%
x < 60 and x < 100

# %%
x > 10 and x > 100

# %% [markdown]
# #### or  : Returns True if one of the statements is True

# %%
x < 50 or x < 10

# %%
x < 50 or x > 100

# %%
x > 100 or x > 200

# %% [markdown]
# #### not : Reverse the result, returns False if the result is True

# %%
not(x > 5 and x > 8)

# %%
not(x > 100 or x > 200)

# %% [markdown]
# # Store your name in two variables i.e. f_name and l_name and display full name

# %% [markdown]
# ## String Concatenation

# %% [markdown]
# ### string concatenation is the appending of one string at the end of another string

# %%
f_name="Bilal"
l_name = "Qaisar"
Full_name = f_name + " "+l_name

# %%
print(Full_name)

# %%
print ('Enter the amount of ' +
       'weekly sales in required columns ' +
       "and press enter"      
      )

# %% [markdown]
# # Input Command

# %%
full_name = input("What is your name: ")

# %%
print(full_name)

# %%
type(full_name)

# %%
No_of_hours= float(input("Enter the number of hours: "))

# %%
type(No_of_hours)

# %%
price = int(input("Enter the price: "))

# %%
type(price)

# %% [markdown]
# ## Case / Task:
# ### write a program to calculate the sale price of an item after the discount is subtracted given the 20% discount rate. Take original price from user.

# %% [markdown]
# * Get the price of item from user
# * Discount rate is 20%
# * Calculate the 20% discount amount from the original price
# * Subtract the discount from the original price
# * Display the sale price

# %%
# Get the price of item from user
original_price=float(input("Enter original price: "))
# Discount rate is 20%
discount_rate=0.20
# Calculate the 20% discount amount from the original price
discount= original_price * discount_rate
# Subtract the discount from the original price
discounted_price= original_price-discount
# Display the sale price
# Using concatenation, format and f-string methodes.
print("The sale price is " + str(discounted_price))
print("The sale price is", discounted_price)
print("The sale price is {}".format(discounted_price))
print(f"The sale price is {discounted_price}")
# Out:
# Enter original price: 100
# The sale price is 80.0
# The sale price is 80.0
# The sale price is 80.0
# The sale price is 80.0

# %% [markdown]
# # Escape Characters
# * backslash ( \ ) escape character

# %%
print("The cat says "meow"")

# %%
print("\"I don't know what happened,\"")

# %%
# class work

# Output: "I don't know what happened," he said quickly.

# %% [markdown]
# * \t : For one Tab space.Inserts horizontal spacing (4 to 8)

# %%
print("one\ttwo")

# %% [markdown]
# * \n: Inserts a newline (line feed) character.

# %%
print("one\ntwo")

# %%
print("how are you today?")
#        ==> "\n\t" - insert a new line + Tab command

# %% [markdown]
# ### Operator Precedence (higher to low precedence and left to right if same order)
# * Operator precedence describes the order in which operations are performed.

# %% [markdown]
# # ()
# # **
# # *  , /
# # + , -

# %%
10 + 5
# Out:
# 15

# %%
10 + 5 - 8
# Out:
# 7

# %%
10 + 20 * 30

# %%
Image(filename=r"C:\Users\Aayat\OperatorPrecedence1.jpg")

# %%
10 + (5 * 3)

# %%
5 + 4 - 7 + 3

# %%
100 / 10 * 10

# %%
Image(filename=r"C:\Users\Aayat\OperatorPrecedence2.jpg")

# %% [markdown]
# * Parentheses override all other precedence rules.

# %%
(6 + 3) * (6 + 3)

# %%
Image(filename=r"C:\Users\Aayat\OperatorPrecedence.jpg")
