# %% [markdown]
# # Dictionaries

# %% [markdown]
# ### A dictionary is an object that stores a collection of data. Each element in a dictionary has two parts: a key and a value. You use a key to locate a specific value.

# %% [markdown]
# # Common use cases
# ## Customer profiles, product-price mapping, model outputs

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222', 'Joanne':'555−3333'}

# %% [markdown]
# # Retrieving a Value from a Dictionary

# %%
phonebook
# Out:
# {'Chris': '555−1111', 'Katie': '555−2222', 'Joanne': '555−3333'}

# %%
phonebook['Chris']
# Out:
# '555−1111'

# %%
phonebook['Kathryn']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-df7a314d232f> in <module>
# ----> 1 phonebook['Kathryn']
#
# KeyError: 'Kathryn'

# %% [markdown]
# # Using the in and not in Operators to Test for a Value in a Dictionary

# %%
if "Chris" in phonebook:
    print(phonebook['Chris'])
# Out:
# 555−1111

# %%
if 'Chris' in phonebook:
    print(phonebook['Chris'])
# Out:
# 555−1111

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222'}
if 'Joanne' not in phonebook:
    print('Joanne is not found.')
# Out:
# Joanne is not found.

# %%
if 'ali' not in phonebook:
    print('ali not found')
# Out:
# ali not found

# %% [markdown]
# # Keep in mind that string comparisons with the in and not in operators are case sensitive.

# %% [markdown]
# # Adding Elements to an Existing Dictionary

# %% [markdown]
# ### Dictionaries are mutable objects. You can add new key-value pairs to a dictionary with an assignment statement in the following general format:
# # dictionary_name[key] = value

# %% [markdown]
# # You cannot have duplicate keys in a dictionary. When you assign a value to an existing key, the new value replaces the existing value.

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222', 'Joanne':'555−3333'}

# %%
phonebook['Joe'] = 5550123

# %%
phonebook
# Out:
# {'Chris': '555−1111',
#  'Katie': '555−2222',
#  'Joanne': '555−3333',
#  'Joe': 5550123}

# %%
phonebook['Chris'] = '555−4444'

# %%
phonebook
# Out:
# {'Chris': '555−4444',
#  'Katie': '555−2222',
#  'Joanne': '555−3333',
#  'Joe': 5550123}

# %% [markdown]
# # Deleting Elements

# %% [markdown]
# # del dictionary_name[key]

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222','Joanne':'555−3333'}

# %%
del phonebook['Chris']

# %%
phonebook
# Out:
# {'Katie': '555−2222', 'Joanne': '555−3333'}

# %%
del phonebook['Chris']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-5ec8412359b8> in <module>
# ----> 1 del phonebook['Chris']
#
# KeyError: 'Chris'

# %% [markdown]
# # Getting the Number of Elements in a Dictionary

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222'}

# %%
len(phonebook)
# Out:
# 2

# %% [markdown]
# # Mixing Data Types in a Dictionary

# %%
test_scores = {'Kayla':[88, 92, 100],'Luis':[95, 74, 81],'Sophie' : [72, 88, 91],'Ethan' : [70, 75, 78]}

# %%
test_scores['Sophie']
# Out:
# [72, 88, 91]

# %%
mixed_up = {'abc':1, 999:'yada yada', (3, 6, 9):[3, 6, 9]}

# %% [markdown]
# # Creating an Empty Dictionary

# %%
phonebook = {}

# %%
phonebook['Chris'] = '555−1111'

# %%
phonebook
# Out:
# {'Chris': '555−1111'}

# %% [markdown]
# # Using the for Loop to Iterate over a Dictionary

# %%
phonebook = {'Chris':'555−1111','Katie':'555−2222','Joanne':'555−3333'}

# %%
for key in phonebook:
    print(key)
# Out:
# Chris
# Katie
# Joanne

# %% [markdown]
# # Build in functions

# %% [markdown]
# # The clear Method

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222'}

# %%
phonebook.clear()

# %%
phonebook
# Out:
# {}

# %% [markdown]
# # The get Method

# %% [markdown]
# # dictionary.get(key, default)
# ## In the general format, dictionary is the name of a dictionary, key is a key to search for in the dictionary, and default is a default value to return if the key is not found.

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222'}

# %%
value = phonebook.get('Katie', 'Entry not found')

# %%
print(value)
# Out:
# 555−2222

# %%
value = phonebook.get('Andy', 'Entry not found')

# %%
print(value)
# Out:
# Entry not found

# %% [markdown]
# # The items Method

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222', 'Joanne':'555−3333'}

# %%
phonebook.items()
# Out:
# dict_items([('Chris', '555−1111'), ('Katie', '555−2222'), ('Joanne', '555−3333')])

# %%
phonebook = {'Chris':'555−1111','Katie':'555−2222', 'Joanne':'555−3333'}

# %%
for key, value in phonebook.items():
    print(key, value)
# Out:
# Chris 555−1111
# Katie 555−2222
# Joanne 555−3333

# %% [markdown]
# # The keys Method
# # The keys method returns all of a dictionary’s keys

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222', 'Joanne':'555−3333'}

# %%
phonebook.keys()
# Out:
# dict_keys(['Chris', 'Katie', 'Joanne'])

# %%
phonebook.values()
# Out:
# dict_values(['555−1111', '555−2222', '555−3333'])

# %% [markdown]
# # The pop Method
# ## The pop method returns the value associated with a specified key and removes that key-value pair from the dictionary. If the key is not found, the method returns a default value. Here is the method’s general format:
# ## dictionary.pop(key, default)

# %%
phonebook = {'Chris':'555−1111','Katie':'555−2222','Joanne':'555−3333'}

# %%
phone_num = phonebook.pop('Chris', 'Entry not found')

# %%
phone_num = phonebook.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-4104de958ac5> in <module>
# ----> 1 phone_num = phonebook.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
phone_num = phonebook.pop('Chris')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-ad3d4e6e1394> in <module>
# ----> 1 phone_num = phonebook.pop('Chris')
#
# KeyError: 'Chris'

# %%
phone_num = phonebook.pop('Katie')

# %%
phonebook = {'Chris':'555−1111','Katie':'555−2222','Joanne':'555−3333'}

# %%
phonebook.pop('Chris')
# Out:
# '555−1111'

# %%
phone_num = phonebook.pop('Katie')

# %%
phone_num
# Out:
# '555−2222'

# %%
phonebook = {'Chris':'555−1111','Katie':'555−2222','Joanne':'555−3333'}

# %%
phonebook.pop('ali', 'Entry not found')
# Out:
# 'Entry not found'

# %% [markdown]
# # The popitem Method

# %% [markdown]
# ## The popitem method performs two actions: (1) It removes the key-value pair that was last added to the dictionary, and (2) it returns that key-value pair as a tuple. Here is the method’s general format:
# ## dictionary.popitem()
# ## You can use an assignment statement in the following general format to assign the returned key and value to individual variables:
# ## k, v = dictionary.popitem()
# ## This type of assignment is known as a multiple assignment because multiple variables are being assigned at once. In the general format, k and v are variables. After the statement executes, k is assigned a randomly selected key from the dictionary, and v is assigned the value associated with that key. The key-value pair is removed from the dictionary.

# %%
phonebook = {'Chris':'555−1111','Katie':'555−2222','Joanne':'555−3333'}

# %%
phonebook.popitem()
# Out:
# ('Joanne', '555−3333')

# %%
key, value = phonebook.popitem()

# %%
key,value
# Out:
# ('Katie', '555−2222')

# %%
phonebook = {'Chris':'555−1111','Katie':'555−2222','Joanne':'555−3333'}

# %%
phonebook.popitem()
# Out:
# ('Joanne', '555−3333')

# %% [markdown]
# # The values Method

# %% [markdown]
# # The values method returns all a dictionary’s values (without their keys) as a dictionary view

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222', 'Joanne':'555−3333'}

# %%
for val in phonebook.values():
    print(val)
# Out:
# 555−1111
# 555−2222
# 555−3333

# %% [markdown]
# # Dictionary Comprehensions

# %% [markdown]
# # A dictionary comprehension is an expression that reads a sequence of input elements and uses those input elements to produce a dictionary. Dictionary comprehensions are similar to list comprehensions

# %% [markdown]
# # the dictionary comprehension begins with a result expression, followed by an iteration expression

# %%
numbers = [1, 2, 3, 4]

# %%
squares = {}
for item in numbers:
    squares[item] = item**2

# %%
squares
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
numbers = [1, 2, 3, 4]
squares = {item:item**2 for item in numbers}

# %%
squares
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
phonebook = {'Chris':'555−1111', 'Katie':'555−2222', 'Joanne':'555−3333'}

# %%
phonebook_copy = {k:v for k,v in phonebook.items()}

# %%
phonebook_copy
# Out:
# {'Chris': '555−1111', 'Katie': '555−2222', 'Joanne': '555−3333'}

# %% [markdown]
# # Using if Clauses with Dictionary Comprehensions

# %% [markdown]
# # {result_expression iteration_expression if_clause}

# %%
populations = {'New York': 8398748, 'Los Angeles': 3990456, 
 
 
 'Chicago': 2705994,'Houston': 2325502, 
 
 
 'Phoenix': 1660272, 'Philadelphia': 1584138}

# %%
largest = {k:v for k,v in populations.items() if v > 2000000}

# %%
largest
# Out:
# {'New York': 8398748,
#  'Los Angeles': 3990456,
#  'Chicago': 2705994,
#  'Houston': 2325502}

# %% [markdown]
# # Sets
#
# ## A set contains a collection of unique and UNORDERED COLLECTION of values and works like a mathematical set.

# %% [markdown]
# # Why use sets
#
# # We can use sets to identify unique customers or products
# # We can find intersections in campaigns i.e. common or shared customers between campaigns

# %% [markdown]
# # two ways to define sets
#
# # one through keyword and other through curly brackets

# %% [markdown]
# # Important
# ## set() needs an iterable (like list, tuple, or string).
#
# ## {} defines a set directly, even with one number.
#
# ## Strings, lists and tuples are iterable; integers are not.

# %%
# set() needs an iterable (like list, tuple, or string).
myset1=set([1,2,3])
myset2 = set((1, 2, 3))
myset3=set('abc')

# %%
myset1
# Out:
# {1, 2, 3}

# %%
myset[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-5445583283da> in <module>
# ----> 1 myset[0]
#
# TypeError: 'set' object is not subscriptable

# %%
myset = set('aaabc')

# %%
# return unique elements only
myset
# Out:
# {'a', 'b', 'c'}

# %%
print(myset1)
print(myset2)
print(myset3)
# Out:
# {1, 2, 3}
# {1, 2, 3}
# {'a', 'b', 'c'}

# %% [markdown]
# # executing myset3 and executing print(myset3) gives different order of abc as sets are unordered collection of elements

# %%
# myset=set(1,2,3) gives error as set takes only one argument 
myset=set(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-80d20163accd> in <module>
#       1 # myset=set(1,2,3) gives error as set takes only one argument
# ----> 2 myset=set(1,2,3)
#
# TypeError: set expected at most 1 argument, got 3

# %%
# myset=set(123) gives error as 'int' object is not iterable

myset=set(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-c28918928725> in <module>
#       1 # myset=set(123) gives error as 'int' object is not iterable
#       2
# ----> 3 myset=set(123)
#
# TypeError: 'int' object is not iterable

# %%
# {} defines a set directly, even with one number.

myset4={1, 2, 3}
myset5 = {'abc', 'def', 'ghi'}

# %%
print(myset4)
print(myset5)
# Out:
# {1, 2, 3}
# {'abc', 'def', 'ghi'}

# %% [markdown]
# # Getting the Number of Elements in a Set

# %%
myset = set([1, 2, 3, 4, 5])
len(myset)
# Out:
# 5

# %%
myset = {1, 2, 3, 4, 5}

# %%
len(myset)
# Out:
# 5

# %% [markdown]
# # Use myset1 = set() to create an empty set
# # dont use myset1={} to create an empty set as it will be considered as dictionary
#
# # then use add fuction to add single values, duplicates if added are ignored

# %%
myset = set()
myset.add(1)
myset.add(2)
myset.add(3)
myset.add(3)

# %%
myset
# Out:
# {1, 2, 3}

# %%
myset1 = {}

# %%
type(myset1)
# Out:
# dict

# %%
myset.add([5, 6])   # TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-1fefa1112bb9> in <module>
# ----> 1 myset.add([5, 6])   # TypeError
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # Update function

# %% [markdown]
# # update function is used to add multiple elements (from any iterable such as list, tuple, string, or another set).

# %%
myset = {1, 2, 3}
myset.update([4, 5, 6])
print(myset)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
myset.update('z')
print(myset)
# Out:
# {1, 2, 3, 4, 5, 6, 'z'}

# %% [markdown]
# # you can even give another set as argument to add multiple elements

# %%
set1 = set([1, 2, 3])
set2 = set([8, 9, 10])
set1.update(set2)

# %%
set1
# Out:
# {1, 2, 3, 8, 9, 10}

# %%
set1.update({'x', 'y'})

# %%
set1
# Out:
# {1, 10, 2, 3, 8, 9, 'x', 'y'}

# %%
myset = set([1, 2, 3])
myset.update('abc')

# %%
print(myset)
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %% [markdown]
# # Deleting elements from set
# ## You can remove an item from a set with either the remove method or the discard method. You pass the item that you want to remove as an argument to either method, and that item is removed from the set. The only difference between the two methods is how they behave when the specified item is not found in the set. The remove method raises a KeyError exception, but the discard method does not raise an exception.

# %%
myset = set([1, 2, 3, 4, 5])

# %%
myset
# Out:
# {1, 2, 3, 4, 5}

# %%
myset.remove(1)
myset
# Out:
# {2, 3, 4, 5}

# %%
myset.discard(5)
myset
# Out:
# {2, 3, 4}

# %%
myset.discard(99)

# %%
myset.remove(99)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-c16a05d3eaa5> in <module>
# ----> 1 myset.remove(99)
#
# KeyError: 99

# %% [markdown]
# # Clear method

# %%
myset = set([1, 2, 3, 4, 5])
myset
# Out:
# {1, 2, 3, 4, 5}

# %%
myset.clear()
myset
# Out:
# set()

# %% [markdown]
# # Using the for Loop to Iterate over a Set

# %%
myset = set(['a', 'b', 'c'])
for val in myset:
    print(val)
# Out:
# a
# b
# c

# %%
myset = {'abc', 'def', 'ghi'}
for val in myset:
    print(val)
# Out:
# abc
# def
# ghi

# %% [markdown]
# # Using the in and not in Operators to Test for a Value in a Set

# %%
myset = set([1, 2, 3])
if 1 in myset:
    print('The value 1 is in the set.')
# Out:
# The value 1 is in the set.

# %%
myset = {1, 2, 3}
if 1 in myset:
    print('The value 1 is in the set.')
# Out:
# The value 1 is in the set.

# %%
myset = set([1, 2, 3])
if 99 not in myset:
    print('The value 99 is not in the set.')
# Out:
# The value 99 is not in the set.

# %% [markdown]
# # Finding the Union of Sets

# %%
set1 = set([1, 2, 3, 4])
set2 = set([3, 4, 5, 6])
set3 = set1.union(set2)

# %%
set3
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set3 = set1.union(set2)

# %%
set3
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # using expression
#
# # set1 | set2

# %%
set1 = set([1, 2, 3, 4])
set2 = set([3, 4, 5, 6])
set3 = set1|set2

# %%
set3
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set3 = set1|set2

# %%
set3
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # Finding the Intersection of Sets

# %%
set1 = set([1, 2, 3, 4])
set2 = set([3, 4, 5, 6])
set3 = set1.intersection(set2)

# %%
set3
# Out:
# {3, 4}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set3 = set1.intersection(set2)

# %%
set3
# Out:
# {3, 4}

# %% [markdown]
# # using expression
#
# ## set1 & set2

# %%
set1 = set([1, 2, 3, 4])
set2 = set([3, 4, 5, 6])
set3 = set1 & set2

# %%
set3
# Out:
# {3, 4}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set3 = set1 & set2

# %%
set3
# Out:
# {3, 4}

# %% [markdown]
# # Finding the Difference of Sets
# # set1.difference(set2)
#
# # The method returns a set that contains the elements that are found in set1 but not in set2.

# %%
set1 = set([1, 2, 3, 4])
set2 = set([3, 4, 5, 6])
set3 = set1.difference(set2)
set3
# Out:
# {1, 2}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set3 = set1.difference(set2)
set3
# Out:
# {1, 2}

# %% [markdown]
# # Using the − operator to find the difference of two sets

# %%
set1 = set([1, 2, 3, 4])
set2 = set([3, 4, 5, 6])
set3 = set1-set2
set3
# Out:
# {1, 2}

# %% [markdown]
# # Finding the Symmetric Difference of Sets
#
# # set1.symmetric_difference(set2)
# # The method returns a set that contains the elements that are found in either set1 or set2 but not both sets.

# %%
set1 = set([1, 2, 3, 4])
set2 = set([3, 4, 5, 6])
set3 = set1.symmetric_difference(set2)
set3
# Out:
# {1, 2, 5, 6}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set3 = set1.symmetric_difference(set2)
set3
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# # Using ^ operator

# %%
set1 = set([1, 2, 3, 4])
set2 = set([3, 4, 5, 6])
set3 = set1 ^ set2
set3
# Out:
# {1, 2, 5, 6}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set3 = set1 ^ set2
set3
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# # Set Comprehensions
# ## A set comprehension is an expression that reads a sequence of input elements and uses those input elements to produce a set. Set comprehensions work like list comprehensions, In fact, set comprehensions are written just like list comprehensions, except that a set comprehension is enclosed in curly braces ({}), and list comprehensions are enclosed in square brackets ([]).

# %%
set1 = set([1, 2, 3, 4, 5])
#The following statement uses a set comprehension to make a copy of the set:
set2 = {item for item in set1}

# %%
set2
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1, 2, 3, 4, 5}
#The following statement uses a set comprehension to make a copy of the set:
set2 = {item for item in set1}

# %%
set2
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# # Let’s look at another example. The following code creates a set of numbers and then creates a second set that contains the squares of all the numbers in the first set:

# %%
set1 = set([1, 2, 3, 4, 5])
set2 = {item**2 for item in set1}
set2
# Out:
# {1, 4, 9, 16, 25}

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {item**2 for item in set1}

# %%
set2
# Out:
# {1, 4, 9, 16, 25}

# %% [markdown]
# #  use an if clause with a set comprehension

# %% [markdown]
# # You can also use an if clause with a set comprehension. For example, suppose a set contains integers and you want to make a second set that contains only the integers from the first set that are less than 10.

# %%
set1 = set([1, 20, 2, 40, 3, 50])
set2 = {item for item in set1 if item < 10}
set2
# Out:
# {1, 2, 3}

# %%
set1 = {1, 20, 2, 40, 3, 50}
set2 = {item for item in set1 if item < 10}
set2
# Out:
# {1, 2, 3}
