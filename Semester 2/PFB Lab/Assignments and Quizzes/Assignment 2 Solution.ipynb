# %% [markdown]
# Shaban Akhtar
# 25L-5575
# Assignment 2

# %%
#Q1

num_tup = (10, 20, 30)
str_tup = ("Fast", "School", "Management")

tuple3 = num_tup + str_tup

print(tuple3)
# Out:
# (10, 20, 30, 'Fast', 'School', 'Management')

# %%
#Q2 ---> Option C

# %%
#Q3
# A list can be changed (mutable) while a tuple cannot be changed after its created (immutable)

# %%
#Q4

myset = set()

myset.add(5)
myset.add(15)
myset.add(25)
myset.add(15)  # duplicate

print(myset)
# Out:
# {25, 5, 15}

# %%
#Q5

dict = {}

dict.update({
    'Chris': '555-1111',
    'Kayla': [88, 92, 100],
    'abc': 1,
    999: 'Joe Group',
    (3, 6, 9): [3, 6, 9]
})


print(dict)
# Out:
# {'Chris': '555-1111', 'Kayla': [88, 92, 100], 'abc': 1, 999: 'Joe Group', (3, 6, 9): [3, 6, 9]}
