# %% [markdown]
# Assessment 01
# **Name:** Shaban Akhtar
# **Course:** Programming for Business
# **Roll_Number:** 25L-5575

# %% [markdown]
# **Question 1**: Print the required formatted text using one print statement.

# %%
print("One, 'two', \"three\", four, \\five\\\nOnce, 'I'\nCaught a fish\n                      '//alive\\\\'")
# Out:
# One, 'two', "three", four, \five\
# Once, 'I'
# Caught a fish
#                       '//alive\\'

# %% [markdown]
# **Question 2**: Answer -> B

# %% [markdown]
# **Question 3** : Answer -> D
# It will be "Hello-world' as the w will not be capitalized in the answer

# %% [markdown]
# **Question 4:** Require the following operations

# %%
x = 10
y = 3
z = x * y

print(f'The variable z is {z}')

length = 2
width = 5

perimeter = 2 * (length + width)

print(f'The Pereimeter is {perimeter}')
# Out:
# The variable z is 30
# The Pereimeter is 14
